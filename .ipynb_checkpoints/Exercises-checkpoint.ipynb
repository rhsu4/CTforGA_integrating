# %% [markdown]
# Exercise on gathering and cleaning:

# %%
link2="https://en.wikipedia.org/wiki/List_of_ISO_3166_country_codes"
link3="https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population"

import pandas as pd

data2=pd.read_html(link2,header=1,flavor="bs4",attrs={'class':"wikitable sortable"})
data3=pd.read_html(link3,header=0,flavor="bs4",attrs={'class':"wikitable sortable"})

# %%
isodata=data2[0].copy()

# %%
isodata.head()
# Out:
#                                     Country name[5]  \
# 0                                       Afghanistan
# 1  Akrotiri and Dhekelia – See United Kingdom, The.
# 2                                     Åland Islands
# 3                                           Albania
# 4                                           Algeria
#
#                              Official state name[6]  \
# 0               The Islamic Republic of Afghanistan
# 1  Akrotiri and Dhekelia – See United Kingdom, The.
# 2                                             Åland
# 3                           The Republic of Albania
# 4       The People's Democratic Republic of Algeria
#
#                                Sovereignty[6][7][8]  \
# 0                                   UN member state
# 1  Akrotiri and Dhekelia – See United Kingdom, The.
# 2                                           Finland
# 3                                   UN member state
# 4                                   UN member state
#
#                                      Alpha-2 code[5]  \
# 0  .mw-parser-output .monospaced{font-family:mono...
# 1   Akrotiri and Dhekelia – See United Kingdom, The.
# 2                                                 AX
# 3                                                 AL
# 4                                                 DZ
#
#                                     Alpha-3 code[5]  \
# 0                                               AFG
# 1  Akrotiri and Dhekelia – See United Kingdom, The.
# 2                                               ALA
# 3                                               ALB
# 4                                               DZA
#
#                                     Numeric code[5]  \
# 0                                               004
# 1  Akrotiri and Dhekelia – See United Kingdom, The.
# 2                                               248
# 3                                               008
# 4                                               012
#
#                           Subdivision code links[3]  \
# 0                                     ISO 3166-2:AF
# 1  Akrotiri and Dhekelia – See United Kingdom, The.
# 2                                     ISO 3166-2:AX
# 3                                     ISO 3166-2:AL
# 4                                     ISO 3166-2:DZ
#
#                                   Internet ccTLD[9]
# 0                                               .af
# 1  Akrotiri and Dhekelia – See United Kingdom, The.
# 2                                               .ax
# 3                                               .al
# 4                                               .dz

# %%
isodata.columns=isodata.columns.str.replace("\\s|\\[[0-9]+]","",regex=True)
isodata.columns
# Out:
# Index(['Countryname', 'Officialstatename', 'Sovereignty', 'Alpha-2code',
#        'Alpha-3code', 'Numericcode', 'Subdivisioncodelinks', 'InternetccTLD'],
#       dtype='object')

# %%
isodata['Alpha-2code'].str.extract("([A-Z][A-Z])")
# Out:
#        0
# 0     AF
# 1    NaN
# 2     AX
# 3     AL
# 4     DZ
# ..   ...
# 275   WF
# 276   EH
# 277   YE
# 278   ZM
# 279   ZW
#
# [280 rows x 1 columns]

# %%
isodata["iso2"]=isodata['Alpha-2code'].str.extract("([A-Z][A-Z])")
isodata["iso3"]=isodata['Alpha-3code'].str.extract("([A-Z][A-Z][A-Z])")

# %%
isodata.dropna(subset=["iso2","iso3"],inplace=True)
isodata.reset_index(drop=True,inplace=True)
isodata
# Out:
#              Countryname                               Officialstatename  \
# 0            Afghanistan             The Islamic Republic of Afghanistan
# 1          Åland Islands                                           Åland
# 2                Albania                         The Republic of Albania
# 3                Algeria     The People's Democratic Republic of Algeria
# 4         American Samoa                 The Territory of American Samoa
# ..                   ...                                             ...
# 243    Wallis and Futuna  The Territory of the Wallis and Futuna Islands
# 244  Western Sahara [ah]            The Sahrawi Arab Democratic Republic
# 245                Yemen                           The Republic of Yemen
# 246               Zambia                          The Republic of Zambia
# 247             Zimbabwe                        The Republic of Zimbabwe
#
#          Sovereignty                                        Alpha-2code  \
# 0    UN member state  .mw-parser-output .monospaced{font-family:mono...
# 1            Finland                                                 AX
# 2    UN member state                                                 AL
# 3    UN member state                                                 DZ
# 4      United States                                                 AS
# ..               ...                                                ...
# 243           France                                                 WF
# 244    Disputed [ai]                                                 EH
# 245  UN member state                                                 YE
# 246  UN member state                                                 ZM
# 247  UN member state                                                 ZW
#
#     Alpha-3code Numericcode Subdivisioncodelinks InternetccTLD iso2 iso3
# 0           AFG         004        ISO 3166-2:AF           .af   AF  AFG
# 1           ALA         248        ISO 3166-2:AX           .ax   AX  ALA
# 2           ALB         008        ISO 3166-2:AL           .al   AL  ALB
# 3           DZA         012        ISO 3166-2:DZ           .dz   DZ  DZA
# 4           ASM         016        ISO 3166-2:AS           .as   AS  ASM
# ..          ...         ...                  ...           ...  ...  ...
# 243         WLF         876        ISO 3166-2:WF           .wf   WF  WLF
# 244         ESH         732        ISO 3166-2:EH          [aj]   EH  ESH
# 245         YEM         887        ISO 3166-2:YE           .ye   YE  YEM
# 246         ZMB         894        ISO 3166-2:ZM           .zm   ZM  ZMB
# 247         ZWE         716        ISO 3166-2:ZW           .zw   ZW  ZWE
#
# [248 rows x 10 columns]

# %%
isodata[isodata.InternetccTLD.str.startswith("[")]
# Out:
#                                          Countryname  \
# 30                                     Bouvet Island
# 212                               Svalbard Jan Mayen
# 234  United States Minor Outlying Islands (the) [ac]
# 244                              Western Sahara [ah]
#
#                                      Officialstatename    Sovereignty  \
# 30                                       Bouvet Island         Norway
# 212                             Svalbard and Jan Mayen         Norway
# 234  Baker Island, Howland Island, Jarvis Island, J...  United States
# 244               The Sahrawi Arab Democratic Republic  Disputed [ai]
#
#     Alpha-2code Alpha-3code Numericcode Subdivisioncodelinks InternetccTLD  \
# 30           BV         BVT         074        ISO 3166-2:BV           [d]
# 212          SJ         SJM         744        ISO 3166-2:SJ           [w]
# 234          UM         UMI         581        ISO 3166-2:UM          [ad]
# 244          EH         ESH         732        ISO 3166-2:EH          [aj]
#
#     iso2 iso3
# 30    BV  BVT
# 212   SJ  SJM
# 234   UM  UMI
# 244   EH  ESH

# %%
isodata[isodata.InternetccTLD.str.match("(.[a-z][a-z]\\s.[a-z][a-z])")]
# Out:
#                                            Countryname  \
# 27                         Bonaire Sint Eustatius Saba
# 233  United Kingdom of Great Britain and Northern I...
#
#                                      Officialstatename      Sovereignty  \
# 27                    Bonaire, Sint Eustatius and Saba      Netherlands
# 233  The United Kingdom of Great Britain and Northe...  UN member state
#
#     Alpha-2code Alpha-3code Numericcode Subdivisioncodelinks InternetccTLD  \
# 27           BQ         BES         535        ISO 3166-2:BQ   .bq .nl [c]
# 233          GB         GBR         826        ISO 3166-2:GB  .gb .uk [ab]
#
#     iso2 iso3
# 27    BQ  BES
# 233   GB  GBR

# %%
isodata.loc[isodata.InternetccTLD.str.startswith("["),"InternetccTLD"]
# Out:
# 30      [d]
# 212     [w]
# 234    [ad]
# 244    [aj]
# Name: InternetccTLD, dtype: object

# %%
isodata.loc[isodata.InternetccTLD.str.match("(.[a-z][a-z]\\s.[a-z][a-z])"),"InternetccTLD"]
# Out:
# 27      .bq .nl [c]
# 233    .gb .uk [ab]
# Name: InternetccTLD, dtype: object

# %%
isodata.loc[isodata.InternetccTLD.str.match("(.[a-z][a-z]\\s.[a-z][a-z])"),"InternetccTLD"]=['.nl','.uk']

# %%
isodata.loc[isodata.InternetccTLD.str.startswith("["),"InternetccTLD"]=None

# %%
isodata.loc[[30,212,234,244],:]
# Out:
#                                          Countryname  \
# 30                                     Bouvet Island
# 212                               Svalbard Jan Mayen
# 234  United States Minor Outlying Islands (the) [ac]
# 244                              Western Sahara [ah]
#
#                                      Officialstatename    Sovereignty  \
# 30                                       Bouvet Island         Norway
# 212                             Svalbard and Jan Mayen         Norway
# 234  Baker Island, Howland Island, Jarvis Island, J...  United States
# 244               The Sahrawi Arab Democratic Republic  Disputed [ai]
#
#     Alpha-2code Alpha-3code Numericcode Subdivisioncodelinks InternetccTLD  \
# 30           BV         BVT         074        ISO 3166-2:BV          None
# 212          SJ         SJM         744        ISO 3166-2:SJ          None
# 234          UM         UMI         581        ISO 3166-2:UM          None
# 244          EH         ESH         732        ISO 3166-2:EH          None
#
#     iso2 iso3
# 30    BV  BVT
# 212   SJ  SJM
# 234   UM  UMI
# 244   EH  ESH

# %%
isodata.loc[[27,233],:]
# Out:
#                                            Countryname  \
# 27                         Bonaire Sint Eustatius Saba
# 233  United Kingdom of Great Britain and Northern I...
#
#                                      Officialstatename      Sovereignty  \
# 27                    Bonaire, Sint Eustatius and Saba      Netherlands
# 233  The United Kingdom of Great Britain and Northe...  UN member state
#
#     Alpha-2code Alpha-3code Numericcode Subdivisioncodelinks InternetccTLD  \
# 27           BQ         BES         535        ISO 3166-2:BQ           .nl
# 233          GB         GBR         826        ISO 3166-2:GB           .uk
#
#     iso2 iso3
# 27    BQ  BES
# 233   GB  GBR

# %%
whichToDrop=range(2,7)
isodata.drop(labels=isodata.columns[whichToDrop],axis=1,inplace=True)

# %%
isodata.loc[isodata.Countryname.str.endswith("]"),]
# Out:
#                                          Countryname  \
# 8                                     Antarctica [a]
# 13                                     Australia [b]
# 33                             Brunei Darussalam [e]
# 37                                    Cabo Verde [f]
# 51                                   Congo (the) [g]
# 54                                 Côte d'Ivoire [h]
# 59                                       Czechia [i]
# 70                                      Eswatini [j]
# 72             Falkland Islands (the) [Malvinas] [k]
# 76                                        France [l]
# 79             French Southern Territories (the) [m]
# 98                                Holy See (the) [n]
# 118  Korea (the Democratic People's Republic of) [o]
# 119                      Korea (the Republic of) [p]
# 122       Lao People's Democratic Republic (the) [q]
# 131                                        Macao [r]
# 132                              North Macedonia [s]
# 153                                      Myanmar [t]
# 175                                     Pitcairn [u]
# 182                     Russian Federation (the) [v]
# 215                   Syrian Arab Republic (the) [x]
# 216                   Taiwan (Province of China) [y]
# 220                                 Timor-Leste [aa]
# 234  United States Minor Outlying Islands (the) [ac]
# 240                                    Viet Nam [ae]
# 241                    Virgin Islands (British) [af]
# 242                       Virgin Islands (U.S.) [ag]
# 244                              Western Sahara [ah]
#
#                                      Officialstatename InternetccTLD iso2 iso3
# 8    All land and ice shelves south of the 60th par...           .aq   AQ  ATA
# 13                       The Commonwealth of Australia           .au   AU  AUS
# 33            The Nation of Brunei, the Abode of Peace           .bn   BN  BRN
# 37                          The Republic of Cabo Verde           .cv   CV  CPV
# 51                           The Republic of the Congo           .cg   CG  COG
# 54                       The Republic of Côte d'Ivoire           .ci   CI  CIV
# 59                                  The Czech Republic           .cz   CZ  CZE
# 70                             The Kingdom of Eswatini           .sz   SZ  SWZ
# 72                                The Falkland Islands           .fk   FK  FLK
# 76                                 The French Republic           .fr   FR  FRA
# 79             The French Southern and Antarctic Lands           .tf   TF  ATF
# 98                                        The Holy See           .va   VA  VAT
# 118          The Democratic People's Republic of Korea           .kp   KP  PRK
# 119                              The Republic of Korea           .kr   KR  KOR
# 122               The Lao People's Democratic Republic           .la   LA  LAO
# 131  The Macao Special Administrative Region of Chi...           .mo   MO  MAC
# 132                The Republic of North Macedonia[12]           .mk   MK  MKD
# 153               The Republic of the Union of Myanmar           .mm   MM  MMR
# 175    The Pitcairn, Henderson, Ducie and Oeno Islands           .pn   PN  PCN
# 182                             The Russian Federation           .ru   RU  RUS
# 215                           The Syrian Arab Republic           .sy   SY  SYR
# 216                              The Republic of China           .tw   TW  TWN
# 220             The Democratic Republic of Timor-Leste           .tl   TL  TLS
# 234  Baker Island, Howland Island, Jarvis Island, J...          None   UM  UMI
# 240                 The Socialist Republic of Viet Nam           .vn   VN  VNM
# 241                                 The Virgin Islands           .vg   VG  VGB
# 242            The Virgin Islands of the United States           .vi   VI  VIR
# 244               The Sahrawi Arab Democratic Republic          None   EH  ESH

# %%
isodata.Countryname=isodata.Countryname.str.replace("\\[.+?\\]","",regex=True)
isodata.loc[isodata.Countryname.str.endswith("]"),]
# Out:
# Empty DataFrame
# Columns: [Countryname, Officialstatename, InternetccTLD, iso2, iso3]
# Index: []

# %%
isodata=isodata.apply(lambda x: x.str.strip())

# %%
isodata.to_csv("isodata.csv",index=False)
isodata
# Out:
#            Countryname                               Officialstatename  \
# 0          Afghanistan             The Islamic Republic of Afghanistan
# 1        Åland Islands                                           Åland
# 2              Albania                         The Republic of Albania
# 3              Algeria     The People's Democratic Republic of Algeria
# 4       American Samoa                 The Territory of American Samoa
# ..                 ...                                             ...
# 243  Wallis and Futuna  The Territory of the Wallis and Futuna Islands
# 244     Western Sahara            The Sahrawi Arab Democratic Republic
# 245              Yemen                           The Republic of Yemen
# 246             Zambia                          The Republic of Zambia
# 247           Zimbabwe                        The Republic of Zimbabwe
#
#     InternetccTLD iso2 iso3
# 0             .af   AF  AFG
# 1             .ax   AX  ALA
# 2             .al   AL  ALB
# 3             .dz   DZ  DZA
# 4             .as   AS  ASM
# ..            ...  ...  ...
# 243           .wf   WF  WLF
# 244          None   EH  ESH
# 245           .ye   YE  YEM
# 246           .zm   ZM  ZMB
# 247           .zw   ZW  ZWE
#
# [248 rows x 5 columns]

# %%
regiondata=data3[0].copy()
regiondata.head()
# Out:
#   Rank Country / Dependency    Region  Population % of world         Date  \
# 0    –                  NaN     World  7923476000        NaN  16 Jan 2022
# 1    1                China      Asia  1411778724      17.8%   1 Nov 2020
# 2    2                India      Asia  1386866394      17.5%  16 Jan 2022
# 3    3        United States  Americas   333061898      4.20%  16 Jan 2022
# 4    4         Indonesia[b]      Asia   271350000      3.42%  31 Dec 2020
#
#   Source (official or from the United Nations)  \
# 0                             UN projection[1]
# 1                        2020 census result[2]
# 2                 National population clock[3]
# 3                 National population clock[4]
# 4                  National annual estimate[5]
#
#                                                Notes
# 0                                                NaN
# 1  The census figure refers to mainland China, ex...
# 2  The figure includes the population of India-ad...
# 3  Includes the 50 states and the District of Col...
# 4                                                NaN

# %%
WhichToDrop=list(set(range(8))-set([1,2]))
WhichToDrop
# Out:
# [0, 3, 4, 5, 6, 7]

# %%
regiondata.drop(labels=regiondata.columns[WhichToDrop],axis=1,inplace=True)
regiondata
# Out:
#                     Country / Dependency    Region
# 0                                    NaN     World
# 1                                  China      Asia
# 2                                  India      Asia
# 3                          United States  Americas
# 4                           Indonesia[b]      Asia
# ..                                   ...       ...
# 237                   Niue (New Zealand)   Oceania
# 238                Tokelau (New Zealand)   Oceania
# 239                         Vatican City    Europe
# 240  Cocos (Keeling) Islands (Australia)   Oceania
# 241    Pitcairn Islands (United Kingdom)   Oceania
#
# [242 rows x 2 columns]

# %%
regiondata.Region.value_counts()
# Out:
# Africa      56
# Asia        55
# Europe      52
# Americas    51
# Oceania     27
# World        1
# Name: Region, dtype: int64

# %%
regiondata=regiondata[regiondata.Region!="World"]
regiondata.reset_index(drop=True,inplace=True)
regiondata
# Out:
#                     Country / Dependency    Region
# 0                                  China      Asia
# 1                                  India      Asia
# 2                          United States  Americas
# 3                           Indonesia[b]      Asia
# 4                               Pakistan      Asia
# ..                                   ...       ...
# 236                   Niue (New Zealand)   Oceania
# 237                Tokelau (New Zealand)   Oceania
# 238                         Vatican City    Europe
# 239  Cocos (Keeling) Islands (Australia)   Oceania
# 240    Pitcairn Islands (United Kingdom)   Oceania
#
# [241 rows x 2 columns]

# %%
regiondata.columns=["Country","Region"]

# %%
regiondata[regiondata["Country"].str.endswith("]")]
# Out:
#            Country  Region
# 3     Indonesia[b]    Asia
# 8        Russia[b]  Europe
# 13        Egypt[b]  Africa
# 17       Turkey[b]    Asia
# 62   Kazakhstan[b]    Asia
# 90   Azerbaijan[b]    Asia
# 130     Georgia[b]    Asia
# 161      Cyprus[c]    Asia

# %%
regiondata.Country=regiondata.Country.str.replace("\\[.+?\\]","",regex=True)

# %%
regiondata[['Country', 'CountryMain']] = regiondata['Country'].str.split('(', 1, expand=True)
# Out:
# /Users/JoseManuel/anaconda3/envs/Evans_GovAnalytics/lib/python3.7/site-packages/pandas/core/frame.py:3641: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]

# %%
#regiondata[regiondata.CountryMain]
regiondata[~pd.isna(regiondata.CountryMain)]
# Out:
#                                            Country    Region  \
# 102                                     Hong Kong       Asia
# 135                                   Puerto Rico   Americas
# 166                                         Macau       Asia
# 182                              French Polynesia    Oceania
# 183                                 New Caledonia    Oceania
# 188                                          Guam    Oceania
# 189                                       Curaçao   Americas
# 193                                         Aruba   Americas
# 195                                        Jersey     Europe
# 197                           U.S. Virgin Islands   Americas
# 201                                   Isle of Man     Europe
# 204                                Cayman Islands   Americas
# 205                                       Bermuda   Americas
# 206                                      Guernsey     Europe
# 207                                American Samoa    Oceania
# 208                      Northern Mariana Islands    Oceania
# 209                                     Greenland   Americas
# 213                                 Faroe Islands     Europe
# 214                      Turks and Caicos Islands   Americas
# 215                                  Sint Maarten   Americas
# 218                                  Saint Martin   Americas
# 219                                     Gibraltar     Europe
# 221                                         Åland     Europe
# 222                        British Virgin Islands   Americas
# 224                                  Cook Islands    Oceania
# 225                                      Anguilla   Americas
# 227                             Wallis and Futuna    Oceania
# 229                              Saint Barthélemy   Americas
# 230  Saint Helena, Ascension and Tristan da Cunha     Africa
# 231                     Saint Pierre and Miquelon   Americas
# 232                                    Montserrat   Americas
# 233                              Falkland Islands   Americas
# 234                              Christmas Island    Oceania
# 235                                Norfolk Island    Oceania
# 236                                          Niue    Oceania
# 237                                       Tokelau    Oceania
# 239                                         Cocos    Oceania
# 240                              Pitcairn Islands    Oceania
#
#                       CountryMain
# 102                        China)
# 135                United States)
# 166                        China)
# 182                       France)
# 183                       France)
# 188                United States)
# 189                  Netherlands)
# 193                  Netherlands)
# 195     British Crown Dependency)
# 197                United States)
# 201     British Crown Dependency)
# 204               United Kingdom)
# 205               United Kingdom)
# 206     British Crown Dependency)
# 207                United States)
# 208                United States)
# 209                      Denmark)
# 213                      Denmark)
# 214               United Kingdom)
# 215                  Netherlands)
# 218                       France)
# 219               United Kingdom)
# 221                      Finland)
# 222               United Kingdom)
# 224                  New Zealand)
# 225               United Kingdom)
# 227                       France)
# 229                       France)
# 230               United Kingdom)
# 231                       France)
# 232               United Kingdom)
# 233               United Kingdom)
# 234                    Australia)
# 235                    Australia)
# 236                  New Zealand)
# 237                  New Zealand)
# 239  Keeling) Islands (Australia)
# 240               United Kingdom)

# %%
regiondata.CountryMain=regiondata.CountryMain.str.replace(")","",regex=False)

# %%
regiondata
# Out:
#                Country    Region                 CountryMain
# 0                China      Asia                        None
# 1                India      Asia                        None
# 2        United States  Americas                        None
# 3            Indonesia      Asia                        None
# 4             Pakistan      Asia                        None
# ..                 ...       ...                         ...
# 236              Niue    Oceania                 New Zealand
# 237           Tokelau    Oceania                 New Zealand
# 238       Vatican City    Europe                        None
# 239             Cocos    Oceania  Keeling Islands (Australia
# 240  Pitcairn Islands    Oceania              United Kingdom
#
# [241 rows x 3 columns]

# %%
regiondata.loc[239,"Country"]="Cocos Islands"
# Out:
# /Users/JoseManuel/anaconda3/envs/Evans_GovAnalytics/lib/python3.7/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /Users/JoseManuel/anaconda3/envs/Evans_GovAnalytics/lib/python3.7/site-packages/pandas/core/indexing.py:723: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
regiondata.iloc[239,0]
# Out:
# 'Cocos Islands'

# %%
regiondata.loc[239,"CountryMain"]="Australia"

# %%
regiondata.iloc[239,2]
# Out:
# 'Australia'

# %%
regiondata.loc[229,"Country"]
# Out:
# 'Saint Barthélemy'

# %%
regiondata=regiondata.apply(lambda x: x.str.strip())

# %%
regiondata.loc[236,"Country"]
# Out:
# 'Niue'

# %%
regiondata.to_csv("regiondata.csv",index=False)
